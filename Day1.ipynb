# %%
x="mythili"
y="vahitha"
print(x)
print(y)
# Out:
# mythili
# vahitha

# %%
a=15;
b=20;
sum_ab=a+b
print(sum_ab)
# Out:
# 35

# %%
price=23.22
print(price)
price=20.07
print(20.07)
# Out:
# 23.22
# 20.07

# %%
is_vaild=True
print(is_vaild)
is_vaild=False
print(is_vaild)
# Out:
# True
# False

# %%
x,y,z=15,18,20
print(x,y,z)
# Out:
# 15 18 20

# %%
age=15
print(age)
age=17
print(age)
age=20
print(age)
# Out:
# 15
# 17
# 20

# %%
value=20
del value
#print(value)#thuis will cause an error since value is deleted

# %%
message="HELLO,WORD!"
print(len(message))
# Out:
# 11

# %%
data=100
print(data)
data=str(data)
print(data)
# Out:
# 100
# 100

# %%
num=3
if num>0:
  print("positive number")
# Out:
# positive number

# %%
age=25
if age<=40:
    print ("eligible to vote")
else:
    print("not eligible to vote")
# Out:
# eligible to vote

# %%
num=-3
if num>0:
  print("positive")
elif num<0:
  print("negative")
else:
  print(zero)
# Out:
# negative

# %%
num=7
if num%2==0:
  print("EVEN")
else:
  print("ODD")
# Out:
# ODD

# %%
num=8
if num>0:
  if num%2==0:
    print("postive and even")
# Out:
# postive and even

# %%
x=50
if x==50:print("python is code")
# Out:
# python is code

# %%
num=12
print("EVEN")if num%2==0 else ("ODD")
# Out:
# EVEN

# %%
text="I love python programming."
if "python"in text:
  print("String contains'python'")
# Out:
# String contains'python'

# %%
lnum=15
if num%3==0 and num%5==0:
  print("divisble by both 3 and 5")
else:
  print("not divisble by 3 and 5")
# Out:
# not divisble by 3 and 5

# %%
year=2024
if(year%4==0 and year%100!=0) or (year%400==0):
     print("Leap year")
else:
  print("not a leap year")
# Out:
# Leap year
